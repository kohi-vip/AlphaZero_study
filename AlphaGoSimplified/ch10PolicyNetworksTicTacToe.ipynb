# %% [markdown]
# # Chapter 10: Policy Netwoks in Tic Tac Toe
#
#
#
# ***
# *“All you need is lots and lots of data and lots of information about what the right
# answer is, and you’ll be able to train a big neural net to do what you want.”*
#
# -- Geoffrey Hinton
# ***
#
#
#
# What you'll learn in this chapter:
# * What is a convolutional neural network
# * Building a fast policy network and a strong policy network in Tic Tac Toe
# * Generating expert moves to train the two policy networks in Tic Tac Toe
# * Implementing a mixed MCTS game strategy in Tic Tac Toe
#
#
# In the previous chapter, you learned the basics of deep learning and
# applied it to the coin game. Specifically, you generated expert moves in the
# game and used them to train two policy networks: a fast policy network with just
# one hidden layer and a strong policy network with three hidden layers.
# In this chapter, you’ll learn to use deep neural networks to train a fast policy network
#
# and a strong policy network in Tic Tac Toe. Different from the previous chapter, the
# two neural networks in this chapter include a new type of layers, convolutional layers,
# which are different from the fully-connected dense layer. While dense layers treat
# inputs as one-dimensional vectors, convolutional layers treat images or game boards
# as multi-dimensional objects and extract spatial features from them. Convolutional
# layers can greatly improve the predictive power of neural networks. This, in turn,
# makes the game strategies that use these policy networks more intelligent.
#
# To generate expert moves in Tic Tac Toe, you’ll use the MiniMax algorithm with
# alpha-beta pruning that we developed in Chapter 6. You’ll use the board positions as
# inputs (Xs) and the expert moves as the targets (ys). Since there are nine potential
# next moves for a player in each step, we’ll treat this as a multi-category classification
# problem and use supervised learning to train the two policy neural networks by using
# the board positions and expert moves. The two trained policy networks will be used
# in the AlphaGo algorithm later in this book.
#
# We’ll use the trained fast policy network later in the book to roll out games in MCTS
# when implementing the AlphaGo algorithm. In contrast, we’ll use the trained strong policy network to help select which next move to use when expanding the game
# tree in MCTS. To gain insight on how the strong policy network can be used in the
# final AlphaGo algorithm, you’ll learn to augment the Monte Carlo Tree Search with
# the trained strong policy network in this chapter. Specifically, instead of selecting
# moves based on upper confidence bounds for trees (UCT) scores alone, you’ll select
# moves based on both UCT scores and the probability distribution from the trained
# strong policy network.We call the agent who selects moves this way the mixed MCTS
# agent. You’ll show that the mixed MCTS agent is more intelligent than the traditional
# MCTS agent that you developed in Chapter 8.

# %% [markdown]
# # 1. What Are Convolutional Layers?

# %%
import numpy as np

board = np.array([[1,0,0],
                   [1,-1,-1],
                   [1,0,0]]).reshape(-1,3,3,1)

# %%
# Create a vertical filter
vertical_filter = np.array([[0,1,0], 
                   [0,1,0],
                   [0,1,0]]).reshape(3,3,1,1)

# %%
import tensorflow as tf

# Apply the filter on the game board
result=tf.nn.conv2d(board,vertical_filter,strides=1,padding="SAME")
# Print it results
print(result.numpy().reshape(3,3))
# Out:
# [[ 2 -1 -1]
#  [ 3 -1 -1]
#  [ 2 -1 -1]]

# %% [markdown]
# # 2.  Deep Learning in Tic Tac Toe

# %% [markdown]
# ## 2.2. Generate Expert Moves in Tic Tac Toe

# %%
from utils.ch06util import MiniMax_ab

def expert(env):
    move = MiniMax_ab(env)
    return move    

def non_expert(env):
    if np.random.rand()<0.5:
        move = MiniMax_ab(env)
    else:
        move = env.sample()
    return move

# %%
from utils.ttt_simple_env import ttt
from copy import deepcopy

# Initiate the game environment
env=ttt()
# Define the one_game() function
def one_game(episode):
    history = []
    state=env.reset()  
    # The nonexpert moves firsts half the time
    if episode%2==0:
        action=non_expert(env)
        state,reward,done,_=env.step(action)
    while True:   
        action=expert(env) 
        if episode%2==0:
            statei=deepcopy(-state)
        else:
            statei=deepcopy(state)            
        actioni=deepcopy(action)
        # record board position and the move
        history.append((statei,actioni))
        state,reward,done,_=env.step(action)
        if done:
            break
        action=non_expert(env)
        state,reward,done,_=env.step(action)     
        if done:
            break
    return history

# Simulate one game and print out results
history=one_game(0)
print(history)
# Out:
# [(array([ 0,  0,  0,  0,  0,  0,  0,  0, -1]), 5), (array([ 0,  0,  0, -1,  1,  0,  0,  0, -1]), 8), (array([ 0,  0,  0, -1,  1, -1,  0,  1, -1]), 2)]

# %%
# simulate the game 10000 times and record all games
results = []        
for episode in range(10000):
    history=one_game(episode)
    results+=history
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 results = []
#       3 for episode in range(10000):
# ----> 4     history=one_game(episode)
#       5     results+=history
#
# Cell In[5], line 12, in one_game(episode)
#      10 # The nonexpert moves firsts half the time
#      11 if episode%2==0:
# ---> 12     action=non_expert(env)
#      13     state,reward,done,_=env.step(action)
#      14 while True:
#
# Cell In[4], line 9, in non_expert(env)
#       7 def non_expert(env):
#       8     if np.random.rand()<0.5:
# ----> 9         move = MiniMax_ab(env)
#      10     else:
#      11         move = env.sample()
#
# File h:\AZ_project\AlphaGoSimplified\utils\ch06util.py:55, in MiniMax_ab(env)
#      53     return m
#      54 # See what's the best response from the opponent
# ---> 55 opponent_payoff=maximized_payoff_ttt(env_copy,\
#      56                              reward,done,-2,-2)
#      57 # Opponent's payoff is the opposite of your payoff
#      58 my_payoff=-opponent_payoff
#
# File h:\AZ_project\AlphaGoSimplified\utils\ch06util.py:26, in maximized_payoff_ttt(env, reward, done, alpha, beta)
#      24 state,reward,done,info=env_copy.step(m)
#      25 # If I make this move, what's the opponent's response?
# ---> 26 opponent_payoff=maximized_payoff_ttt(env_copy,\
#      27                              reward,done,alpha,beta)
#      28 # Opponent's payoff is the opposite of your payoff
#      29 my_payoff=-opponent_payoff
#
# File h:\AZ_project\AlphaGoSimplified\utils\ch06util.py:26, in maximized_payoff_ttt(env, reward, done, alpha, beta)
#      24 state,reward,done,info=env_copy.step(m)
#      25 # If I make this move, what's the opponent's response?
# ---> 26 opponent_payoff=maximized_payoff_ttt(env_copy,\
#      27                              reward,done,alpha,beta)
#      28 # Opponent's payoff is the opposite of your payoff
#      29 my_payoff=-opponent_payoff
#
#     [... skipping similar frames: maximized_payoff_ttt at line 26 (3 times)]
#
# File h:\AZ_project\AlphaGoSimplified\utils\ch06util.py:26, in maximized_payoff_ttt(env, reward, done, alpha, beta)
#      24 state,reward,done,info=env_copy.step(m)
#      25 # If I make this move, what's the opponent's response?
# ---> 26 opponent_payoff=maximized_payoff_ttt(env_copy,\
#      27                              reward,done,alpha,beta)
#      28 # Opponent's payoff is the opposite of your payoff
#      29 my_payoff=-opponent_payoff
#
# File h:\AZ_project\AlphaGoSimplified\utils\ch06util.py:23, in maximized_payoff_ttt(env, reward, done, alpha, beta)
#      21 # iterate through all possible moves
#      22 for m in env.validinputs:
# ---> 23     env_copy=deepcopy(env)
#      24     state,reward,done,info=env_copy.step(m)
#      25     # If I make this move, what's the opponent's response?
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:

# %%
import pickle

# save the simulation data on your computer
with open('files/games_ttt.p', 'wb') as fp:
    pickle.dump(results,fp)
# read the data and print out the first 10 observations       
with open('files/games_ttt.p', 'rb') as fp:
    games = pickle.load(fp)
print(games[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 # save the simulation data on your computer
#       4 with open('files/games_ttt.p', 'wb') as fp:
# ----> 5     pickle.dump(results,fp)
#       6 # read the data and print out the first 10 observations
#       7 with open('files/games_ttt.p', 'rb') as fp:
#
# NameError: name 'results' is not defined

# %% [markdown]
# # 3. Two Policy Networks in Tic Tac Toe

# %% [markdown]
# ## 3.1. Create Two Neural Networks for Tic Tac Toe

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten

fast_model = Sequential()
fast_model.add(Conv2D(filters=128, 
    kernel_size=(3,3),padding="same",activation="relu",
                 input_shape=(3,3,1)))
fast_model.add(Flatten())
fast_model.add(Dense(units=64, activation="relu"))
fast_model.add(Dense(units=64, activation="relu"))
fast_model.add(Dense(9, activation='softmax'))
fast_model.compile(loss='categorical_crossentropy',
                   optimizer='adam', 
                   metrics=['accuracy'])

# %%
strong_model = Sequential()
strong_model.add(Conv2D(filters=128, 
    kernel_size=(3,3),padding="same",activation="relu",
                 input_shape=(3,3,1)))
strong_model.add(Flatten())
strong_model.add(Dense(units=64, activation="relu"))
strong_model.add(Dense(units=64, activation="relu"))
strong_model.add(Dense(units=64, activation="relu"))
strong_model.add(Dense(9, activation='softmax'))
strong_model.compile(loss='categorical_crossentropy',
                   optimizer='adam', 
                   metrics=['accuracy'])

# %% [markdown]
# ## 3.2. Train the Two Policy Networks

# %%
import pickle
import numpy as np
with open('files/games_ttt.p','rb') as fp:
    games=pickle.load(fp)

states=[]
actions=[]
for x in games:
    state=x[0]
    action=to_categorical(x[1]-1,9)
    states.append(state)
    actions.append(action)

X=np.array(states).reshape((-1, 3, 3, 1))
y=np.array(actions).reshape((-1, 9))
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[9], line 4
#       2 import numpy as np
#       3 with open('files/games_ttt.p','rb') as fp:
# ----> 4     games=pickle.load(fp)
#       6 states=[]
#       7 actions=[]
#
# EOFError: Ran out of input

# %%
# Train the fast policy network for 100 epochs
fast_model.fit(X, y, epochs=100, verbose=1)
fast_model.save('files/fast_ttt.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Train the fast policy network for 100 epochs
# ----> 2 fast_model.fit(X, y, epochs=100, verbose=1)
#       3 fast_model.save('files/fast_ttt.h5')
#
# NameError: name 'X' is not defined

# %% [markdown]
# It takes about five minutes to train the model. Once done, we save the trained model in the local foder.
#
# Next, we train the strong policy network for 100 epochs as well.

# %%
strong_model.fit(X, y, epochs=100, verbose=1)
strong_model.save('files/strong_ttt.h5')
# Out:
# Epoch 1/100
# 60/60 [==============================] - 1s 2ms/step - loss: 2.1581 - accuracy: 0.1590
# Epoch 2/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1.9251 - accuracy: 0.3159
# Epoch 3/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1.6227 - accuracy: 0.4137
# Epoch 4/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1.4329 - accuracy: 0.4806
# Epoch 5/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1.2848 - accuracy: 0.5429
# Epoch 6/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1.1726 - accuracy: 0.5669
# Epoch 7/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1.1026 - accuracy: 0.5999
# Epoch 8/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1.0566 - accuracy: 0.5973
# Epoch 9/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9886 - accuracy: 0.6308
# Epoch 10/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9730 - accuracy: 0.6203
# Epoch 11/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9438 - accuracy: 0.6391
# Epoch 12/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9163 - accuracy: 0.6339
# Epoch 13/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9077 - accuracy: 0.6470
# Epoch 14/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8616 - accuracy: 0.6637
# Epoch 15/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8772 - accuracy: 0.6574
# Epoch 16/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8563 - accuracy: 0.6658
# Epoch 17/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8430 - accuracy: 0.6679
# Epoch 18/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8367 - accuracy: 0.6616
# Epoch 19/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8372 - accuracy: 0.6647
# Epoch 20/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7986 - accuracy: 0.6815
# Epoch 21/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7987 - accuracy: 0.6773
# Epoch 22/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7917 - accuracy: 0.6883
# Epoch 23/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7892 - accuracy: 0.6825
# Epoch 24/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8011 - accuracy: 0.6815
# Epoch 25/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7701 - accuracy: 0.6972
# Epoch 26/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7673 - accuracy: 0.6899
# Epoch 27/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7693 - accuracy: 0.6867
# Epoch 28/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7528 - accuracy: 0.6956
# Epoch 29/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7536 - accuracy: 0.6904
# Epoch 30/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7573 - accuracy: 0.6909
# Epoch 31/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7509 - accuracy: 0.6940
# Epoch 32/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7449 - accuracy: 0.6946
# Epoch 33/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7391 - accuracy: 0.6888
# Epoch 34/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7355 - accuracy: 0.6977
# Epoch 35/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7350 - accuracy: 0.6893
# Epoch 36/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7426 - accuracy: 0.6946
# Epoch 37/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7331 - accuracy: 0.6998
# Epoch 38/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7318 - accuracy: 0.7040
# Epoch 39/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7290 - accuracy: 0.6972
# Epoch 40/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7253 - accuracy: 0.7008
# Epoch 41/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7249 - accuracy: 0.6935
# Epoch 42/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7359 - accuracy: 0.6899
# Epoch 43/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7203 - accuracy: 0.6946
# Epoch 44/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7219 - accuracy: 0.7040
# Epoch 45/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7152 - accuracy: 0.6961
# Epoch 46/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7147 - accuracy: 0.6961
# Epoch 47/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7190 - accuracy: 0.7019
# Epoch 48/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7074 - accuracy: 0.6956
# Epoch 49/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7061 - accuracy: 0.6993
# Epoch 50/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7149 - accuracy: 0.6919
# Epoch 51/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7163 - accuracy: 0.6935
# Epoch 52/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7190 - accuracy: 0.6925
# Epoch 53/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6945 - accuracy: 0.6967
# Epoch 54/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7090 - accuracy: 0.6977
# Epoch 55/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7032 - accuracy: 0.6998
# Epoch 56/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7013 - accuracy: 0.6925
# Epoch 57/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6942 - accuracy: 0.7061
# Epoch 58/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7012 - accuracy: 0.7019
# Epoch 59/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7050 - accuracy: 0.6987
# Epoch 60/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7137 - accuracy: 0.6893
# Epoch 61/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6955 - accuracy: 0.7035
# Epoch 62/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6995 - accuracy: 0.6951
# Epoch 63/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6957 - accuracy: 0.7076
# Epoch 64/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6950 - accuracy: 0.6899
# Epoch 65/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.7008
# Epoch 66/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7020 - accuracy: 0.6998
# Epoch 67/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.7008
# Epoch 68/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6988 - accuracy: 0.6987
# Epoch 69/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.7035
# Epoch 70/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.7035
# Epoch 71/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.7008
# Epoch 72/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6963 - accuracy: 0.6993
# Epoch 73/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.6946
# Epoch 74/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6900 - accuracy: 0.7076
# Epoch 75/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.6998
# Epoch 76/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6968 - accuracy: 0.6935
# Epoch 77/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.7003
# Epoch 78/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.6946
# Epoch 79/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6966 - accuracy: 0.6987
# Epoch 80/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.6993
# Epoch 81/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.6972 - accuracy: 0.6914
# Epoch 82/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.7071
# Epoch 83/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.6982
# Epoch 84/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.7071
# Epoch 85/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.6982
# Epoch 86/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.7014
# Epoch 87/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.7055
# Epoch 88/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6827 - accuracy: 0.6982
# Epoch 89/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.7019
# Epoch 90/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.6951
# Epoch 91/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.6967
# Epoch 92/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.7035
# Epoch 93/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.6993
# Epoch 94/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.7014
# Epoch 95/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.7024
# Epoch 96/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6888 - accuracy: 0.7008
# Epoch 97/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.7066
# Epoch 98/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6761 - accuracy: 0.7045
# Epoch 99/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.7071
# Epoch 100/100
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.7035

# %% [markdown]
# # 4. A Mixed MCTS Algorithm
#
#
# ## 4.1 Augment the UCT formula with a strong policy network

# %% [markdown]
# ## 4.2. Mixed MCTS in Tic Tac Toe

# %% [markdown]
# In the local module *ch10util*, we define a *mix_select()* function as follows:

# %% [markdown]
# ```python
# gamma=10
# def mix_select(env,ps,counts,wins,losses,temperature):
#     # a dictionary of mixed scores for all next moves
#     scores={}
#     # the ones not visited get the priority
#     for k in env.validinputs:
#         if counts[k]==0:
#             return k
#     # total number of simulations conducted
#     N=sum([v for k,v in counts.items()])
#     # calculate scores
#     for k,v in counts.items():
#         # the third term based on policy network
#         weighted_pi=gamma*ps[k]/(1+counts[k])
#         if v==0:
#             scores[k]=weighted_pi
#         else:
#             # vi for each next move
#             vi=(wins.get(k,0)-losses.get(k,0))/v
#             # exploratoin term
#             exploration=temperature*sqrt(log(N)/counts[k])
#             # mixed score
#             scores[k]=vi+exploration+weighted_pi
#     # Select the next move with the highest UCT score
#     return max(scores,key=scores.get)
# ```

# %% [markdown]
# ```python
# def next_move(ps,counts,wins,losses):
#     # See which action is most promising
#     scores={}
#     # calculate scores
#     for k,v in counts.items():
#         # the third term based on policy network
#         weighted_pi=gamma*ps[k]/(1+counts[k])
#         # vi for each next move
#         vi=(wins.get(k,0)-losses.get(k,0))/v
#         # mixed score
#         scores[k]=vi+weighted_pi
#     # Select the next move with the score
#     return max(scores,key=scores.get)
# ```

# %% [markdown]
# ```python
# def mix_mcts(env,model,num_rollouts=100,temperature=1.4):
#     # if there is only one valid move left, take it
#     if len(env.validinputs)==1:
#         return env.validinputs[0]
#     # create three dictionaries counts, wins, losses
#     counts={}
#     wins={}
#     losses={}
#     for move in env.validinputs:
#         counts[move]=0
#         wins[move]=0
#         losses[move]=0
#     # priors from the policy network
#     state = env.state.reshape(-1,3,3,1)
#     if env.turn=="X":
#         action_probs= model(state)
#     else:
#         action_probs= model(-state)
#     ps={}
#     for a in sorted(env.validinputs):
#         ps[a]=np.squeeze(action_probs)[a-1]
#     # roll out games
#     for _ in range(num_rollouts):
#         # selection
#         move=mix_select(env,ps,counts,wins,losses,temperature)
#         # expansion
#         env_copy, done, reward=expand(env,move)
#         # simulation
#         reward=simulate(env_copy,done,reward)
#         # backpropagate
#         counts,wins,losses=backpropagate(\
#             env,move,reward,counts,wins,losses)
#     # make the move
#     return next_move(ps,counts,wins,losses)
# ```

# %% [markdown]
# # 5. Mixed MCTS versus UCT MCTS

# %%
from utils.ttt_simple_env import ttt
from utils.ch10util import mix_mcts
from utils.ch08util import mcts
from tensorflow.keras.models import load_model

# load the trained strong policy network
model=load_model("files/strong_ttt.h5")

# Initiate the game environment
env=ttt()
state=env.reset() 
num_rollouts=200
results=[]
for i in range(100):
    state=env.reset() 
    if i%2==0:
        action=mcts(env,num_rollouts=num_rollouts)
        state, reward, done, info = env.step(action)
    while True:
        action=mix_mcts(env,model,num_rollouts=num_rollouts)  
        state, reward, done, info = env.step(action)
        if done:
            # result is 1 if mixed MCTS wins
            if reward!=0:
                results.append(1) 
            else:
                results.append(0)    
            break  
        action=mcts(env,num_rollouts=num_rollouts)   
        state, reward, done, info = env.step(action)
        if done:
            # result is -1 if mixed MCTS loses
            if reward!=0:
                results.append(-1) 
            else:
                results.append(0)    
            break

# %%
# count how many times mixed MCTS won
wins=results.count(1)
print(f"mixed MCTS won {wins} games")
# count how many times mix MCTS lost
losses=results.count(-1)
print(f"mixed MCTS lost {losses} games")  
# count how many tie games
ties=results.count(0)
print(f"the game is tied {ties} times")
# Out:
# mixed MCTS won 29 games
# mixed MCTS lost 10 games
# the game is tied 61 times
